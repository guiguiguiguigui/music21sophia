# %%
# %load_ext music21.ipython21
import pitch_cartesian as pc

# %%
firstSong = pc.anotherMXL[0]

# %%
firstSong
# Out:
# '../wikifonia_en_chords_lyrics/wikifonia-10018.mxl'

# %%
s = pc.consonanceOneSong(firstSong, returnScore=True)

# %%
s.show()

# %%
pc.consonanceOneSong(pc.anotherMXL[2], returnScore=True).show()

# %%
pc.consonanceOneSong(pc.anotherMXL[1000], returnScore=True).show()
